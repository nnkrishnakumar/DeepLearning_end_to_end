# %%
# Lecture_2:

# why we are using deep learning?

# > huge data

# > computer memory and hardware advancement. (GPU,TPU,RAM)

# > Python and Opensource Ecosystem

# > Pytourch and tensorflow

# > Cloud and AI Boom

# %% [markdown]
# 1> Introduction tensorflow and keras and python
# 2> Why deep Learning becoming so popular
# 3> What is Neuron?
# 4> What is Neural Network?
# 5> Install tensorflow
# 6> Pytorch vs Tensorflow vs Keras
# 7> Digit Classification
# 8> Activation Function
# 9> Derivatives
# 10> Matrix Basics
# 11> Loss and cost function
# 12> Gradient descent in Neural Network
# 13> Neural Network from scratch
# 14> Stochastic vs Batch vs Mini Batch Gradient Descent.
# 15> Chain Rule
# 16> Tensorfboard Introduction
# 17> GPU Benchmark
# 18> Customer Churn prediction using ANN
# 19> Precision, recall, F1 score
# 20>Dropout Regularization
# 21> Imbalance dataset
#
# 22> Computer Vision and it application
# 22> Convolutional Neural Network
# 23> Image classification dataset cifar10 and cifar100 dataset using cnn
# 24> Padding and stride
# 25> Data Augumentation
# 26> Transfer Learning
# 27>Image classification vs Object detection vs Image segmentation
# 28> Popular datasets for computer vision: ImageNetl, Coco and Google Open images
#
# 30> Sliding window Object Detection
# 31> YOLO Algorithm
# 32> Object detection using YOLO v4and pre trained Model.
# 33> What is RNN?
# 34> Types of RNN
# 35> Vanishing grandients
# 36> LSTM
# 37> GRU(Gated Recurrent Units) Explained.
# 38> Bidirectional RNN
# 39> Converting words to numbers, word embeddings
# 40> Word embedding using keras embedding layer
# 41> what is word2vec?
# 42> Word2Vec Part 2.
# 43> Distributed Training On NVIDIA DGX station A100
# 44> Tensoflow input pipeline|tf dataset
# 45> Optimize Tensorflow Pipeline Performance: Prefetch & cache
# 46> What is BERT?
# 47> Text classification using BERT
# 48> tf serving tutorial
# 49> Quantization in Deep Learning

# %%
Lecture_3:

# What is a Neuron?
